# %% [markdown]
# <a href="https://colab.research.google.com/github/khyp1210/Class2021Fall/blob/main/2020.11.22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# parameter setting
amp = 1          # range [0.0, 1.0]
sr = 10000       # sampling rate, Hz
dur = 0.5        # in seconds
freq = 100.0     # sine frequency, Hz
phase = np.pi/2  # phase, radian

# %%
# generate samples
nSamp = sr * dur
samples = np.arange(1, nSamp+1)

# %%
# convert samples to time
t = samples/sr

# %%
# convert time to angle in radian
theta0 = t * 2*np.pi * freq

# %%
# shift angle by phase
theta = theta0 + phase

# %%
# generate signal by sin-phasor
s = amp * np.sin(theta)

# %%
# plot the entire signal
plt.plot(t, s, ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
# plot a certain of signals
sampleRng = np.arange(0,100)
plt.plot(t[sampleRng], s[sampleRng], ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
ipd.Audio(s, rate=10000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; dur = 1; freq = 440; phase = 0
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
amp = 1; sr = 10000; phase = 0

A0  = 220.00
C1  = 261.62
G1  = 391.99
A1  = 440.00
D1  = 293.66
E1  = 329.62	 
Eb = 622.25 
F1  = 349.22 
G0  = 195.99
B0 = 246.94

# %%
# Heart and Soul

notes = [C1, C1, E1, E1, A0, A0, C1, C1, D1, D1, F1, F1, G0, G0, B0, B0, \
         C1, C1, E1, E1, A0, A0, C1, C1, D1, D1, F1, F1, G0, G0, B0, B0, \
         C1, C1, C1, C1, B0, A0, B0, C1, D1, E1, E1, E1, E1, D1, C1, D1, E1, F1, \
         G1, C1, A1, G1, F1, E1, D1, C1]

durs = [0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.5, 0.5, 1, 0.2, 0.35, 0.20, 0.3, 0.20, 0.5, 0.5, 0.5, 1, 0.2, 0.35, 0.20, 0.3, 0.20, 0.5, \
        1, 1.2, 0.20, 0.35, 0.2, 0.5, 0.5, 0.5]

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
